# %%
import requests
import json
import pandas as pd

# %%
api_key = "ef4c5176645445238294a9fbf5fa8ad1"
subscription_name = "comp90024"
url = "https://gateway.api.epa.vic.gov.au/environmentMonitoring/v1/sites/parameters?environmentalSegment=air"

headers = {
    "User-Agent": 'curl/8.4.0',
    "Cache-Contrl": "no-cache",
    'X-API-Key': api_key
}


response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
        
else:
    print("query fail:", response.status_code)

print(response.text)
# Out:
# {
#   "totalRecords" : 93,
#   "records" : [
#     {
#       "siteID" : "77062cb7-3e3b-4984-b6d0-03dda76177f2",
#       "siteName" : "Box Hill",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8287277,
#           145.1324
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 30.25,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "1022"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 30.25,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 21.83,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 107.64,
#                   "totalSample" : 310,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1030"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "c69ed768-34d2-4d72-86f3-088c250758a8",
#       "siteName" : "Alphington",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.7784081,
#           145.0306
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 27.08,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "1022"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "SO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.8,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1011"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "CO",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.4,
#                   "unit" : "ppm",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1026"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "8HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T22:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.53,
#                   "unit" : "ppm",
#                   "confidence" : 108.33,
#                   "totalSample" : 104
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 27.08,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 30.19,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Poor",
#                   "healthAdviceColor" : "#E47400",
#                   "healthCode" : "1031"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2.08,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 28.55,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "O3",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1001"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 45.06,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1017"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "NO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 33,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1006"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "ee780b50-0240-4c7e-99f8-0df759caf3a3",
#       "siteName" : "Churchill",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.3043137,
#           146.414932
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 1.13,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 4.7,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1016"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 1.13,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1021"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.16,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1029"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "cddf953a-b932-4918-97ea-1d19583d507a",
#       "siteName" : "Traralgon South",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.29585,
#           146.5392
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.43,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.43,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 6.56,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 288,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "70584bae-a7e7-4ae9-adf5-1e8e92b15386",
#       "siteName" : "Traralgon",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1942825,
#           146.531464
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 2.77,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.29,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "NO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 7,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1006"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 17.41,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1016"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "O3",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 14,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1001"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2.77,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1021"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.52,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1029"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 70,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "SO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1011"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "CO",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "confidence" : 0,
#                   "totalSample" : 0
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "8HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "confidence" : 0,
#                   "totalSample" : 0
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "69fa2d5e-557c-457a-9103-21bc2609f5eb",
#       "siteName" : "Tyers North",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.12967,
#           146.4828
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.25,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.25,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 7.21,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 288,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "69088979-01eb-4b48-9535-22b6d69421ec",
#       "siteName" : "Dandenong",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.98576,
#           145.1987
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 35.47,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "1022"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "NO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "confidence" : 0,
#                   "totalSample" : 0
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 35.47,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 18.65,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1030"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 55.71,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1017"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2.33,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 25.22,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "O3",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1001"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "f5c385fd-c136-4398-99b0-35696b711b7b",
#       "siteName" : "Moe",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.1864662,
#           146.258331
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 2.47,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 7.73,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1016"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2.47,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1021"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 3.7,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1029"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "dd8279c0-018d-469b-92c7-49eeeecd27de",
#       "siteName" : "Boolarra South",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.44398,
#           146.2742
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.55,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 4.55,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.86,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 288,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "33fd2638-98ff-4b6c-8b75-5feecae706df",
#       "siteName" : "Traralgon East",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.19631,
#           146.5621
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.95,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 4.95,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 13.26,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 288,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "9999"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "1adaf80a-f20f-4fd3-8fa1-60d87acfce61",
#       "siteName" : "Boolarra",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.36981,
#           146.2751
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 4.68,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 4.68,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 10.51,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 288,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "9999"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "aa39a036-4514-4b51-aaf4-6276e98b036c",
#       "siteName" : "Yinnar",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.32779,
#           146.3371
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 5.28,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.28,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 7.83,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 288,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "9999"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "032edf91-3cb9-42be-8ff3-70d3f56dba68",
#       "siteName" : "Morwell East",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.229393,
#           146.424454
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "SO2",
#           "averageValue" : 0.41,
#           "unit" : "ppb",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1011"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "confidence" : 0,
#                   "totalSample" : 0
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 3.01,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 77.08,
#                   "totalSample" : 222,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1029"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.33,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 70,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "CO",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.16,
#                   "unit" : "ppm",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1026"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "8HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T22:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.17,
#                   "unit" : "ppm",
#                   "confidence" : 108.33,
#                   "totalSample" : 104
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "SO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.41,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1011"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "confidence" : 0,
#                   "totalSample" : 0
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "5fa9b7aa-651d-4c9d-96b1-8f6813b2d933",
#       "siteName" : "Geelong South",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.17356,
#           144.3703
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 3.51,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.38,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "CO",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.12,
#                   "unit" : "ppm",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1026"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "8HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T22:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.25,
#                   "unit" : "ppm",
#                   "confidence" : 107.29,
#                   "totalSample" : 104
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "SO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 0.15,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1011"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 21.95,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1016"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "NO2",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 8,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1006"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 3.51,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1021"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 15.23,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1030"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "O3",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 9,
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1001"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 70,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "3a0e909b-a278-4c5b-8786-975c5ef4c4c9",
#       "siteName" : "Willow Grove",
#       "siteType" : "Sensor",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -38.07072,
#           146.1779
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "Particles",
#           "averageValue" : 7.1,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "9999"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "Particles",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 7.1,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 100,
#                   "totalSample" : 12,
#                   "healthAdvice" : "Good",
# ...
#                   "unit" : "ppb",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1001"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "9348c1f5-60c5-4c35-b4f1-1f0931ab1415",
#       "siteName" : "Mooroolbark",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.77512,
#           145.3284
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 31.93,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "1022"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2.3,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 31.93,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 22.78,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 105.56,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1030"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 25.66,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "O3",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "confidence" : 0,
#                   "totalSample" : 0
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 53.53,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 75,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1017"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "031354b3-b6a2-403b-aae3-79e18f69c957",
#       "siteName" : "Footscray",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.80266,
#           144.8778
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 34.33,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "1022"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 52.37,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1017"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 34.33,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 32.44,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Poor",
#                   "healthAdviceColor" : "#E47400",
#                   "healthCode" : "1031"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 34.33,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 32.44,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Poor",
#                   "healthAdviceColor" : "#E47400",
#                   "healthCode" : "1031"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "78dbc892-d9e9-490b-94a6-baf1ca72c36c",
#       "siteName" : "Brooklyn",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -37.8220978,
#           144.8471
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 32.43,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Fair",
#           "healthAdviceColor" : "#EEC900",
#           "healthCode" : "1022"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "API",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 2.34,
#                   "unit" : "none",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 32.96,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1016"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 32.43,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1022"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 30.95,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 103.82,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Poor",
#                   "healthAdviceColor" : "#E47400",
#                   "healthCode" : "1031"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "Visibility",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 25.12,
#                   "unit" : "km",
#                   "confidence" : 108.33,
#                   "totalSample" : 13
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "82e215ca-e0e5-4a00-9357-98d53b04311b",
#       "siteName" : "Bendigo",
#       "siteType" : "Standard",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.77841,
#           144.300064
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 5.93,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.93,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1021"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 9.69,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 106.94,
#                   "totalSample" : 311,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1030"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "siteID" : "c21b7785-acfa-45c0-83c6-7700760bf8f1",
#       "siteName" : "Porepunkah",
#       "siteType" : "Incident",
#       "geometry" : {
#         "type" : "Point",
#         "coordinates" : [
#           -36.70419,
#           146.9169
#         ]
#       },
#       "siteHealthAdvices" : [
#         {
#           "since" : "2024-05-09T05:00:00Z",
#           "until" : "2024-05-09T06:00:00Z",
#           "healthParameter" : "PM2.5",
#           "averageValue" : 1.85,
#           "unit" : "&micro;g/m&sup3;",
#           "healthAdvice" : "Good",
#           "healthAdviceColor" : "#42A93C",
#           "healthCode" : "1021"
#         }
#       ],
#       "parameters" : [
#         {
#           "name" : "PM2.5",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 1.85,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1021"
#                 }
#               ]
#             },
#             {
#               "timeSeriesName" : "24HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-08T06:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 8.72,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 312,
#                   "healthAdvice" : "Fair",
#                   "healthAdviceColor" : "#EEC900",
#                   "healthCode" : "1030"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "name" : "PM10",
#           "timeSeriesReadings" : [
#             {
#               "timeSeriesName" : "1HR_AV",
#               "readings" : [
#                 {
#                   "since" : "2024-05-09T05:00:00Z",
#                   "until" : "2024-05-09T06:00:00Z",
#                   "averageValue" : 5.44,
#                   "unit" : "&micro;g/m&sup3;",
#                   "confidence" : 108.33,
#                   "totalSample" : 13,
#                   "healthAdvice" : "Good",
#                   "healthAdviceColor" : "#42A93C",
#                   "healthCode" : "1016"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
file_path = "data.json"

# 将数据写入 JSON 文件
with open(file_path, "w") as json_file:
    json.dump(response.json(), json_file)

# %%
def json_to_dataframe(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)

    # 将JSON数组转换为DataFrame
    df = pd.json_normalize(data['records'])

    # 显示DataFrame
    print(df.head())
    return df

# %%
df= json_to_dataframe(file_path)

# 显示 DataFrame 的前几行数据
print(df.head())
# Out:
#                                  siteID         siteName  siteType  \
# 0  77062cb7-3e3b-4984-b6d0-03dda76177f2         Box Hill  Standard
# 1  c69ed768-34d2-4d72-86f3-088c250758a8       Alphington  Standard
# 2  ee780b50-0240-4c7e-99f8-0df759caf3a3        Churchill  Standard
# 3  cddf953a-b932-4918-97ea-1d19583d507a  Traralgon South    Sensor
# 4  70584bae-a7e7-4ae9-adf5-1e8e92b15386        Traralgon  Standard
#
#                                    siteHealthAdvices  \
# 0  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 1  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 2  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 3  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 4  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
#
#                                           parameters geometry.type  \
# 0  [{'name': 'PM2.5', 'timeSeriesReadings': [{'ti...         Point
# 1  [{'name': 'SO2', 'timeSeriesReadings': [{'time...         Point
# 2  [{'name': 'PM10', 'timeSeriesReadings': [{'tim...         Point
# 3  [{'name': 'Particles', 'timeSeriesReadings': [...         Point
# 4  [{'name': 'API', 'timeSeriesReadings': [{'time...         Point
#
#         geometry.coordinates cameraImageURL timeLapseURL
# 0    [-37.8287277, 145.1324]            NaN          NaN
# 1    [-37.7784081, 145.0306]            NaN          NaN
# 2  [-38.3043137, 146.414932]            NaN          NaN
# 3      [-38.29585, 146.5392]            NaN          NaN
# 4  [-38.1942825, 146.531464]            NaN          NaN
#                                  siteID         siteName  siteType  \
# 0  77062cb7-3e3b-4984-b6d0-03dda76177f2         Box Hill  Standard
# 1  c69ed768-34d2-4d72-86f3-088c250758a8       Alphington  Standard
# 2  ee780b50-0240-4c7e-99f8-0df759caf3a3        Churchill  Standard
# 3  cddf953a-b932-4918-97ea-1d19583d507a  Traralgon South    Sensor
# 4  70584bae-a7e7-4ae9-adf5-1e8e92b15386        Traralgon  Standard
#
#                                    siteHealthAdvices  \
# 0  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 1  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 2  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 3  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
# 4  [{'since': '2024-05-09T05:00:00Z', 'until': '2...
#
#                                           parameters geometry.type  \
# 0  [{'name': 'PM2.5', 'timeSeriesReadings': [{'ti...         Point
# 1  [{'name': 'SO2', 'timeSeriesReadings': [{'time...         Point
# 2  [{'name': 'PM10', 'timeSeriesReadings': [{'tim...         Point
# 3  [{'name': 'Particles', 'timeSeriesReadings': [...         Point
# 4  [{'name': 'API', 'timeSeriesReadings': [{'time...         Point
#
#         geometry.coordinates cameraImageURL timeLapseURL
# 0    [-37.8287277, 145.1324]            NaN          NaN
# 1    [-37.7784081, 145.0306]            NaN          NaN
# 2  [-38.3043137, 146.414932]            NaN          NaN
# 3      [-38.29585, 146.5392]            NaN          NaN
# 4  [-38.1942825, 146.531464]            NaN          NaN

# %% [markdown]
# ## preview数据集

# %%
df.columns
# Out:
# Index(['siteID', 'siteName', 'siteType', 'siteHealthAdvices', 'parameters',
#        'geometry.type', 'geometry.coordinates', 'cameraImageURL',
#        'timeLapseURL'],
#       dtype='object')

# %%
df['siteName'].unique()
# Out:
# array(['Box Hill', 'Alphington', 'Churchill', 'Traralgon South',
#        'Traralgon', 'Tyers North', 'Dandenong', 'Moe', 'Boolarra South',
#        'Traralgon East', 'Boolarra', 'Yinnar', 'Morwell East',
#        'Geelong South', 'Willow Grove', 'Yallourn North', 'Point Cook',
#        'Flynns Creek', 'Melbourne CBD', 'Tyers', 'Callignee',
#        'Hernes Oak', 'Wangaratta', 'Morwell South', 'Brighton', 'Echuca',
#        'Healesville', 'Warrnambool', 'Mildura', 'Horsham', 'Altona North',
#        'Ballarat', 'Bairnsdale', 'Castlemaine', 'Beechworth', 'Benalla',
#        'Ararat', 'Cobden', 'Camperdown', 'Colac', 'Maffra', 'Gisborne',
#        'Macedon', 'Lancefield', 'Kyneton', 'Heathcote', 'Kinglake',
#        'Daylesford', 'Heywood', 'Hamilton', 'Kerang', 'Lorne',
#        'Mallacoota', 'Shepparton', 'Orbost', 'Sale', 'Myrtleford',
#        'Mansfield', 'Portland', 'Ouyen', 'Torquay', 'Wonthaggi',
#        'Warragul', 'Yarrawonga', 'Wodonga', 'Broadford', 'Yarra Glen',
#        'Sunbury', 'Lakes Entrance', 'Leongatha', 'Bacchus Marsh',
#        'Warburton', 'Drysdale', 'Rutherglen', 'Bright', 'Macleod',
#        'Swan Hill', 'Spotswood', 'Wallan', 'Rosedale', 'Kingsville',
#        'Flynn', 'Glengarry', 'Melton', 'Mooroolbark', 'Footscray',
#        'Brooklyn', 'Bendigo', 'Porepunkah'], dtype=object)

# %% [markdown]
# ## 预处理

# %%
column_0_data = df.iloc[:, 0]
column_1_data = df.iloc[:, 1]
column_4_data = df.iloc[:, 4]
df_main_v2 = pd.DataFrame()
for i, item in enumerate(column_4_data):
    if isinstance(item, float):
        
        continue  # 跳过 float 类型的数据
    
    if isinstance(item, list) :
        for type in item: #循环每种监控器类型读到的数据
            if type["name"] ==  'PM2.5':
                for tsr in type['timeSeriesReadings']: # 读取每种时间段的数据
                    tsr_name = tsr['timeSeriesName']
                    # 遍历 readings
                    for reading in tsr['readings']:
                        # 将每个 reading 转换为 DataFrame
                        df_temp = pd.DataFrame([reading])
                        # 添加 name 和 timeSeriesName 列
                        df_temp['name'] = 'PM2.5'
                        df_temp['timeSeriesName'] = tsr_name
                        df_temp['sit_id'] = column_0_data[i]
                        df_temp['sit_name'] = column_1_data[i]
                        # 将结果添加到主 DataFrame
                        df_main_v2 = pd.concat([df_main_v2, df_temp])

# 重新排序列
df_main_v2 = df_main_v2[['sit_id','sit_name', 'name', 'timeSeriesName', 'since', 'until', 'averageValue', 'unit', 'confidence', 'totalSample', 'healthAdvice', 'healthAdviceColor', 'healthCode']]

# 显示 DataFrame
# Out:
# sit_id               77062cb7-3e3b-4984-b6d0-03dda76177f2
# sit_name                                         Box Hill
# name                                                PM2.5
# timeSeriesName                                     1HR_AV
# since                                2024-05-09T05:00:00Z
# until                                2024-05-09T06:00:00Z
# averageValue                                        30.25
# unit                                     &micro;g/m&sup3;
# confidence                                         108.33
# totalSample                                            13
# healthAdvice                                         Fair
# healthAdviceColor                                 #EEC900
# healthCode                                           1022
# Name: 0, dtype: object

# %%
print(df_main_v2.iloc[4])
# Out:
# sit_id               ee780b50-0240-4c7e-99f8-0df759caf3a3
# sit_name                                        Churchill
# name                                                PM2.5
# timeSeriesName                                     1HR_AV
# since                                2024-05-09T05:00:00Z
# until                                2024-05-09T06:00:00Z
# averageValue                                         1.13
# unit                                     &micro;g/m&sup3;
# confidence                                         108.33
# totalSample                                            13
# healthAdvice                                         Good
# healthAdviceColor                                 #42A93C
# healthCode                                           1021
# Name: 0, dtype: object

# %%
len(df_main_v2)
# Out:
# 56

# %%
df_main_v2.to_csv("air_data.csv", index=False)

# %%
df_3 = pd.read_csv("air_data.csv")

# %%
filtered_rows = df_3[df_3['timeSeriesName'] == '24HR_AV']

# %%
filtered_rows.to_csv("air_24h+df.csv", index=False)
